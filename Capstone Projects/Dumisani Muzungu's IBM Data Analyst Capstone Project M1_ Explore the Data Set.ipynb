# %% [markdown]
# # **Survey Dataset Exploration**

# %% [markdown]
# ## Objectives

# %% [markdown]
# -   Load the dataset that will used thru the capstone project.
# -   Explore the dataset.
# -   Get familier with the data types.

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# Import the required libraries.

# %%
import pandas as pd
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The dataset is available on the IBM Cloud or Kaggle.

# %% [markdown]
# below we create a dataFrame for our dataset

# %%
df_survey = pd.read_csv("/projects_csv/survey_data_demographics.csv")

# %%
# pd.set_option('display.max_column', 11399)
df_survey
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11393       25136  I am a developer by profession      Yes
# 11394       25137  I am a developer by profession      Yes
# 11395       25138  I am a developer by profession      Yes
# 11396       25141  I am a developer by profession      Yes
# 11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %% [markdown]
# ## Explore the data set

# %% [markdown]
# prints the top 5 rows of the dataset to get a feel of how the dataset will look.

# %% [markdown]
# Displays the top 5 rows and columns from your dataset.

# %%
df_survey.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# ## To Find out the number of rows and columns

# %% [markdown]
# Prints the number of rows in the dataset.

# %%
# your code goes here
print('The number of rows in the dataframe is ' + str(df_survey.shape[0]) +'.')
# Out:
# The number of rows in the dataframe is 11398.

# %% [markdown]
# Prints the number of columns in the dataset.

# %%
print('The number of columns in the dataframe is ' + str(df_survey.shape[1]) +'.')
# Out:
# The number of columns in the dataframe is 68.

# %% [markdown]
# ## To Identify the data types of each column

# %% [markdown]
# Prints the datatype of all columns.

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_survey.dtypes)
# Out:
# Respondent          int64
# MainBranch         object
# Hobbyist           object
# OpenSourcer        object
# OpenSource         object
# Employment         object
# Country            object
# Student            object
# EdLevel            object
# UndergradMajor     object
# EduOther           object
# OrgSize            object
# DevType            object
# YearsCode          object
# Age1stCode         object
# YearsCodePro       object
# CareerSat          object
# JobSat             object
# MgrIdiot           object
# MgrMoney           object
# MgrWant            object
# JobSeek            object
# LastHireDate       object
# LastInt            object
# FizzBuzz           object
# JobFactors         object
# ResumeUpdate       object
# CurrencySymbol     object
# CurrencyDesc       object
# CompTotal         float64
# CompFreq           object
# ConvertedComp     float64
# WorkWeekHrs       float64
# WorkPlan           object
# WorkChallenge      object
# ...

# %% [markdown]
# ## To Print the mean age of the survey participants.

# %%
print('The mean age of the survey participants is ', df_survey['Age'].mean().__round__(1))
# Out:
# The mean age of the survey participants is  30.8

# %% [markdown]
# The dataset is the result of a world wide survey. Print how many unique countries are there in the Country column.

# %%
print('There are', df_survey['Country'].nunique(), 'unique countries in the survey:')

print('\nCountry                               Respondants')      

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_survey['Country'].value_counts())
# Out:
# There are 135 unique countries in the survey:
#
# Country                               Respondants
# United States                                3127
# India                                         897
# United Kingdom                                821
# Germany                                       708
# Canada                                        432
# France                                        339
# Brazil                                        325
# Australia                                     285
# Netherlands                                   254
# Spain                                         251
# Russian Federation                            208
# Poland                                        205
# Italy                                         188
# Sweden                                        162
# Switzerland                                   148
# Ukraine                                       108
# South Africa                                  102
# ...

# %% [markdown]
# ## Authors

# %% [markdown]
# Dumisani Muzungu

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Done By        | Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2024-01-17       | 0.1     | Dumisani Muzungu| Exploratory Data Analysis|
